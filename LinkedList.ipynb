# %%
#Traversing in LinkedList
def traverse_linked_list(head):
    curr = head
    while curr:
        print(curr.data)
        curr = curr.next

# %%
#Searching a Element in Linkedlist
def search_linked_list(head, target):

    while head is not None:
        if head.data == target:
            return True
        
        head = head.next

    return False

# %%
# Define the ListNode class
class ListNode:
    def __init__(self, data=0, next=None):
        self.data = data
        self.next = next

# Helper function to create a linked list from a list of values
def create_linked_list(values):
    if not values:
        return None
    head = ListNode(values[0])
    current = head
    for value in values[1:]:
        current.next = ListNode(value)
        current = current.next
    return head

# Test cases
if __name__ == "__main__":
    # Test 1: Empty list
    print("Test 1: Empty list")
    head = create_linked_list([])
    print(search_linked_list(head, 5))  # Expected output: False
# Out:
# Test 1: Empty list
# False

# %%
# Python function to find the length of the linked list
def find_length(head):
    curr = head
    count = 0
    while curr is not None:
        count += 1
        curr = curr.next
    return count

# %%
# Define the ListNode class
class ListNode:
    def __init__(self, data=0, next=None):
        self.data = data
        self.next = next

# Helper function to create a linked list from a list of values
def create_linked_list(values):
    if not values:
        return None
    head = ListNode(values[0])
    current = head
    for value in values[1:]:
        current.next = ListNode(value)
        current = current.next
    return head

# Test cases
if __name__ == "__main__":
    # Test 1: Empty list
    print("Test 1: Empty list")
    head = create_linked_list([])
    print(find_length(head))  # Expected output: 0
# Out:
# Test 1: Empty list
# 0
# Test 2: Single element
# 1
# Test 3: Multiple elements
# 5

# %%
# Python function to insert a node at the beggining of the linked
def insert_at_end(head, value):
    #New node is created
    newnode = Node(value)

    #newnode -> next to head
    newnode.next = head

    #Move the Head to new Node
    head = newnode

    return newnode

# %%
# Definition of a singly linked list node
class Node:
    def __init__(self, data=0, next=None):
        self.data = data
        self.next = next

# Function to insert a new node at the beginning of the linked list
def insert_at_beginning(head, value):
    # Create a new node with the given value
    new_node = Node(value)
    # Set the next pointer of the new node to the current head
    new_node.next = head
    # Return the new node as the new head of the linked list
    return new_node

# Helper function to print a linked list
def print_linked_list(head):
    current = head
    while current is not None:
        print(current.data, end=" -> ")
        current = current.next
    print("None")

# Test cases
if __name__ == "__main__":
    # Test 1: Insert into an empty list
    print("Test 1: Insert into an empty list")
    head = None
    head = insert_at_beginning(head, 10)
    print_linked_list(head)  # Expected output: 10 -> None

    # Test 2: Insert into a list with one element
    print("Test 2: Insert into a list with one element")
    head = Node(20)
    head = insert_at_beginning(head, 15)
    print_linked_list(head)  # Expected output: 15 -> 20 -> None

    # Test 3: Insert into a list with multiple elements
    print("Test 3: Insert into a list with multiple elements")
    head = Node(30)
    head.next = Node(40)
    head.next.next = Node(50)
    head = insert_at_beginning(head, 25)
    print_linked_list(head)  # Expected output: 25 -> 30 -> 40 -> 50 -> None
# Out:
# Test 1: Insert into an empty list
# 10 -> None
# Test 2: Insert into a list with one element
# 15 -> 20 -> None
# Test 3: Insert into a list with multiple elements
# 25 -> 30 -> 40 -> 50 -> None

# %%
# Python function to insert a node at the end of the linked
# list
def insert_at_end(head, value):
    #new node creation
    newnode = Node(value)
    #add edge case scenario
    if head is None:
        return newnode
    
    curr = head

    #attach tail to new node
    while curr.next is not None:
        curr = curr.next
        
    curr.next = newnode

    return head

# %%
# Definition of a singly linked list node
class Node:
    def __init__(self, data=0, next=None):
        self.data = data
        self.next = next

# Function to print a linked list
def print_linked_list(head):
    current = head
    while current is not None:
        print(current.data, end=" -> ")
        current = current.next
    print("None")

# Test cases
if __name__ == "__main__":
    # Test 1: Insert into an empty list
    print("Test 1: Insert into an empty list")
    head = None
    head = insert_at_end(head, 10)
    print_linked_list(head)  # Expected output: 10 -> None

    # Test 2: Insert into a list with one element
    print("Test 2: Insert into a list with one element")
    head = Node(20)
    head = insert_at_end(head, 30)
    print_linked_list(head)  # Expected output: 20 -> 30 -> None

    # Test 3: Insert into a list with multiple elements
    print("Test 3: Insert into a list with multiple elements")
    head = Node(40)
    head.next = Node(50)
    head.next.next = Node(60)
    head = insert_at_end(head, 70)
    print_linked_list(head)  # Expected output: 40 -> 50 -> 60 -> 70 -> None
# Out:
# Test 1: Insert into an empty list
# 10 -> None
# Test 2: Insert into a list with one element
# 20 -> 30 -> None
# Test 3: Insert into a list with multiple elements
# 40 -> 50 -> 60 -> 70 -> None

# %%
# Function to insert a node at a specified position
def insertPos(head, pos, data):
    # Handle invalid position
    if pos < 1:
        print("Invalid position!")
        return head  # Return the unmodified list

    # Special case for inserting at the head
    if pos == 1:
        newnode = Node(data)
        newnode.next = head
        return newnode  # New node becomes the head

    # Traverse to find the node just before the insertion point
    count = 1
    curr = head
    while count < pos - 1 and curr is not None:
        curr = curr.next
        count += 1

    # If position is out of range
    if curr is None:
        print("Position out of range!")
        return head

    # Insert the new node
    newnode = Node(data)
    newnode.next = curr.next
    curr.next = newnode

    return head  # Return the head of the updated list

# %%
# Define the Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# Helper function to print the linked list
def print_list(head):
    curr = head
    while curr:
        print(curr.data, end=" -> ")
        curr = curr.next
    print("None")

# Create a sample linked list: 1 -> 2 -> 3
head = Node(1)
head.next = Node(2)
head.next.next = Node(3)

print("Original list:")
print_list(head)

# Test insertion at various positions
print("\nInsert 4 at position 2:")
head = insertPos(head, 2, 4)
print_list(head)

print("\nInsert 5 at position 1 (head):")
head = insertPos(head, 1, 5)
print_list(head)

print("\nInsert 6 at position 6 (invalid):")
head = insertPos(head, 6, 6)
print_list(head)
# Out:
# Original list:
# 1 -> 2 -> 3 -> None
#
# Insert 4 at position 2:
# 1 -> 4 -> 2 -> 3 -> None
#
# Insert 5 at position 1 (head):
# 5 -> 1 -> 4 -> 2 -> 3 -> None
#
# Insert 6 at position 6 (invalid):
# 5 -> 1 -> 4 -> 2 -> 3 -> 6 -> None

# %%
# Python Function to remove the first node
# of the linked list
def removeFirstNode(head):
    if not head:
        return None
    
    temp = head
    head = head.next
    temp = None

    return head

# %%
# Helper function to print the list
def print_list(head):
    curr = head
    while curr:
        print(curr.data, end=" -> ")
        curr = curr.next
    print("None")

# Define a simple Node class for testing
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# Create a linked list: 1 -> 2 -> 3 -> None
head = Node(1)
head.next = Node(2)
head.next.next = Node(3)

print("Original List:")
print_list(head)

# Remove the first node
head = removeFirstNode(head)

print("\nList after removing the first node:")
print_list(head)
# Out:
# Original List:
# 1 -> 2 -> 3 -> None
#
# List after removing the first node:
# 2 -> 3 -> None

# %%
# Python Function to remove the last node of the linked list
def removeLastNode(head):
    # Handle empty list
    if head is None:
        return None

    # Handle single node
    if head.next is None:
        return None

    # Traverse to find the second-to-last node
    curr = head
    while curr.next.next is not None:
        curr = curr.next

    # Remove the last node
    curr.next = None

    return head

# %%
# Helper function to print the linked list
def print_list(head):
    while head:
        print(head.data, end=" -> ")
        head = head.next
    print("None")

# Node class for testing
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# Test case 1: Empty list
head = None
head = removeLastNode(head)
print_list(head)  # Output: None

# Test case 2: Single node
head = Node(1)
head = removeLastNode(head)
print_list(head)  # Output: None

# Test case 3: Multiple nodes
head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head = removeLastNode(head)
print_list(head)  # Output: 1 -> 2 -> None
# Out:
# None
# None
# 1 -> 2 -> None

# %%
# Function to Delete a node at a specified position
def deletePos(head, pos):
    # Handle invalid position
    if pos < 1:
        print("Invalid Position")
        return head

    # Special case for inserting at the head
    if pos == 1:
        return head.next
    # Traverse to find the node just before the insertion point
    count = 1
    curr = head
    while count < pos - 1 and curr is not None:
        curr = curr.next
        count += 1

        # If position is out of bounds
    if curr is None or curr.next is None:
        print("Position out of bounds!")
        return head

    curr.next = curr.next.next

    return head  # Return the head of the updated list

# %%
# Node class for testing
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

# Helper function to print the list
def print_list(head):
    while head:
        print(head.data, end=" -> ")
        head = head.next
    print("None")

# Creating a sample linked list
head = Node(1)
head.next = Node(2)
head.next.next = Node(3)
head.next.next.next = Node(4)

# Test case 1: Delete head
head = deletePos(head, 1)
print_list(head)  # Output: 2 -> 3 -> 4 -> None

# Test case 2: Delete middle node
head = deletePos(head, 2)
print_list(head)  # Output: 2 -> 4 -> None

# Test case 3: Delete out-of-bounds position
head = deletePos(head, 5)
print_list(head)  # Output: 2 -> 4 -> None

# Test case 4: Invalid position
head = deletePos(head, -1)
print_list(head)  # Output: Invalid position! 2 -> 4 -> None
# Out:
# 2 -> 3 -> 4 -> None
# 2 -> 4 -> None
# Position out of bounds!
# 2 -> 4 -> None
# Invalid Position
# 2 -> 4 -> None

# %%
#Doubly LinkedList
class Node:
  
    def __init__(self, data):
        # To store the value or data.
        self.data = data

        # Reference to the previous node
        self.prev = None

        # Reference to the next node
        self.next = None

# %%
# Define the Node class
class Node:
    def __init__(self, data):
        self.data = data
        self.prev = None
        self.next = None

# Function to traverse the doubly linked list 
# in forward direction
def forward_traversal(head):
  
    # Start traversal from the head of the list
    curr = head
    
    # Continue until the current node is 
    # null (end of the list)
    while curr is not None:
      
        # Output data of the current node
        print(curr.data, end=" ")
        
        # Move to the next node
        curr = curr.next
        
    # Print newline after traversal
    print()

# Function to traverse the doubly linked 
# list in backward direction
def backward_traversal(tail):
  
    # Start traversal from the tail of the list
    curr = tail
    
    # Continue until the current node 
    # is null (end of the list)
    while curr is not None:
      
        # Output data of the current node
        print(curr.data, end=" ")
        
        # Move to the previous node
        curr = curr.prev
        
    # Print newline after traversal
    print()

# Sample usage of the doubly linked list 
# and traversal functions
if __name__ == "__main__":
  
    # Create a doubly linked list with 3 nodes
    head = Node(1)
    second = Node(2)
    third = Node(3)

    head.next = second
    second.prev = head
    second.next = third
    third.prev = second

    print("Forward Traversal:")
    forward_traversal(head)

    print("Backward Traversal:")
    backward_traversal(third)
# Out:
# Forward Traversal:
# 1 2 3
# Backward Traversal:
# 3 2 1

# %%
def find_length(head):
#Find Lenght
    curr = head
    count =0
    # Continue until the current node is 
    # null (end of the list)
    while curr is not None:
        curr = curr.next
        count += 1
    
    return count

# %%
def insertBegin(head, data):
    curr = head
    newnode = Node(data)
    newnode.next = head
    if head is not None:
        head.prev = newnode


    return newnode

# %%
# Python Program to insert a node at the beginning 
#of doubly linked list
def insertBegin(head, data):
    curr = head
    newnode = Node(data)
    newnode.next = head
    if head is not None:
        head.prev = newnode


    return newnode

# %%
# Python Program to insert a node at the end of doubly linked list
def insert_end(head, new_data):
    curr = head
    newnode = Node(new_data)
    if head is None:    
        return new_data
    while curr.next is not None:
        curr = curr.next
    
    curr.next = newnode
    newnode.prev = curr

    return head

# %%
# Function to Insert a node at a specific position 
#in the doubly linked list
def insert_at_position(head, pos, new_data):

    newnode = Node(new_data)
    if pos == 1:
        newnode.next = head
        if head is not None:
            head.prev = newnode
        return newnode
    curr = head
    for i in range(1, pos -1):
        if curr is None:
            print("Out ot Bound")
            return head
        curr = curr.next

    if curr is None:
        print("Out ot Bound")
        return head

    newnode.next = curr.next
    newnode.prev = curr
    if curr.next is not None:
        curr.next.prev = newnode
    curr.next = newnode

    return head

# %%
# Node class definition
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

# Print function to display the doubly linked list
def print_list(head):
    curr = head
    while curr:
        print(curr.data, end=" <-> " if curr.next else "\n")
        curr = curr.next

# Test cases
head = Node(10)
second = Node(20)
third = Node(30)

head.next = second
second.prev = head
second.next = third
third.prev = second

print("Original List:")
print_list(head)

# Insert at position 2
head = insert_at_position(head, 2, 15)
print("\nAfter Insertion at Position 2:")
print_list(head)

# Insert at the beginning
head = insert_at_position(head, 1, 5)
print("\nAfter Insertion at the Beginning:")
print_list(head)

# Insert at the end
head = insert_at_position(head, 5, 35)
print("\nAfter Insertion at the End:")
print_list(head)

# Attempt invalid position
head = insert_at_position(head, 10, 50)
# Out:
# Original List:
# 10 <-> 20 <-> 30
#
# After Insertion at Position 2:
# 10 <-> 15 <-> 20 <-> 30
#
# After Insertion at the Beginning:
# 5 <-> 10 <-> 15 <-> 20 <-> 30
#
# After Insertion at the End:
# 5 <-> 10 <-> 15 <-> 20 <-> 35 <-> 30
# Out ot Bound

# %%
# Python Program to delete a node from the 
# beginning of Doubly Linked List
def del_head(head):
    if head is None:
        print(" Empty")
        return head
    
    head = head.next
    if head is not None:
        head.prev = None
    
    return head

# %%
# Python Program to delete a node from the end of 
#Doubly Linked List

def del_last(head):
    curr = head
    while curr.next is not None:
        curr = curr.next
    if curr.prev is not None:
        curr.prev.next = None

    return head

# %%
# Function to delete a node at a specific position 
#in the doubly linked list
def del_pos(head, pos):


    if pos == 1:
        if head is not None:
            head = head.next
            head.prev = None
        return head
    
    curr = head

    for i in range(1, pos -1):
        if curr is None:
            print("Out ot Bound")
            return head
        curr = curr.next

    if curr is None:
        print("Out ot Bound")
        return head

    if curr.next and curr.next is not None:

        curr.next = curr.next.next
        curr.next.prev = curr


    return head

# %%
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

def create_list(values):
    if not values:
        return None
    head = Node(values[0])
    curr = head
    for value in values[1:]:
        new_node = Node(value)
        curr.next = new_node
        new_node.prev = curr
        curr = new_node
    return head

def print_list(head):
    result = []
    curr = head
    while curr is not None:
        result.append(curr.data)
        curr = curr.next
    print("Linked List:", result)

# Test Cases
head = create_list([10, 20, 30, 40, 50])
print("Original List:")
print_list(head)

head = del_pos(head, 3)  # Delete the node at position 3 (value 30)
print("After Deleting Position 3:")
print_list(head)

head = del_pos(head, 1)  # Delete the node at position 1 (head node)
print("After Deleting Head:")
print_list(head)

head = del_pos(head, 5)  # Try to delete a node at position 5 (out of bounds)
print("After Trying to Delete Position 5:")
print_list(head)
# Out:
# Original List:
# Linked List: [10, 20, 30, 40, 50]
# After Deleting Position 3:
# Linked List: [10, 20, 40, 50]
# After Deleting Head:
# Linked List: [20, 40, 50]
# Out ot Bound
# After Trying to Delete Position 5:
# Linked List: [20, 40, 50]

# %%
# Function to insert a node at the beginning of the circular linked list
def insert_at_beginning(last, value):
    new_node = Node(value)

    # If the list is empty, make the new node point to itself and set it as last
    if last is None:
        new_node.next = new_node
        return new_node

    # Insert the new node at the beginning
    new_node.next = last.next
    last.next = new_node

    return last

# %%
# Function to insert a node at the end of a circular linked list
def insert_end(tail, value):
    new_node = Node(value)
    if tail is None:
        # If the list is empty, initialize
        # it with the new node
        tail = new_node
        new_node.next = new_node
    else:
        # Insert new node after the current tail
        # and update the tail pointer
        new_node.next = tail.next
        tail.next = new_node
        tail = new_node
    return tail

# %%
# Function to insert a node at a specific position in a circular linked list
def insertAtPosition(last, data, pos):
    if last is not None:
        if pos != 1:
            print("Posn does not exists")
        newnode = Node(data)
        last = newnode.next
    return last

   
    newnode = Node(data)
    curr = last.next
     #pos ==1
    if pos == 1:
        newnode.next = curr
        last.next = newnode
    return last

    for i in range(1,pos-1):
        if curr is not None:
            curr += 1
            # If position is out of bounds
            if curr == last.next:
                print("Invalid position!")
                return last
        
        newnode.next = curr.next
        curr.next = newnode
        if curr == last:
            last = newnode

    return last

# %%
#206. Reverse Linked List
class Solution(object):
    def reverseList(self, head):
        prev =None
        newnode = None
        curr = head

        while curr:
            newnode = curr.next
            curr.next = prev
            prev= curr
            curr = newnode
        
        return prev
    
# Time - O(n)
# Space - O(1)

# %%
#21. Merge Two Sorted Lists
class Solution(object):
    def mergeTwoLists(self, list1, list2):
        dummy = ListNode()
        current = dummy

        while list1 and list2:
            if list1.val < list2.val:
                current.next = list1
                list1 = list1.next
            else:
                current.next = list2
                list2 = list2.next
            current = current.next
        
        current.next = list1 or list2

        return dummy.next
    
# Time - O(m+n)
# Space - O(1)

# %%
#203. Remove Linked List Elements

class Solution(object):
    def removeElements(self, head, val):
        dummy = ListNode(-1)
        dummy.next = head
        current = dummy
        
        while current.next:
            if current.next.val == val:
                    current.next = current.next.next
            else:
                current = current.next
            
        return dummy.next
    
# Time - O(n)
# Space - O(1)

# %%
#876. Middle of the Linked List
class Solution(object):
    def middleNode(self, head):

        slow = head
        fast = head

        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next

        return slow
# Time - O(n)
# Space - O(1)

# %%
#141. Linked List Cycle

class Solution(object):
    def hasCycle(self, head):
        slow = head
        fast = head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
            if slow is fast:
                return True
        return False
# Time - O(n)
# Space - O(1)

# %%
#234. Palindrome Linked List

class Solution(object):
    def isPalindrome(self, head):
        #edge case scenario
        if not head or not head.next:
            return True

        #find Mid
        slow,fast = head,head
        while fast and fast.next:
            slow = slow.next
            fast = fast.next.next
        
        #rev the 2nd half
        newnode = None
        prev = None
        while slow:
            newnode = slow.next
            slow.next = prev
            prev = slow
            slow = newnode
        
        #compare both
        left,right = head, prev
        while right:
            if left.val != right.val:
                return False
            left = left.next
            right = right.next
        return True

# %%
#160. Intersection of Two Linked Lists
class Solution(object):
    def getIntersectionNode(self, headA, headB):
       
        if not headA or not headB:
            return None
    
        pa = headA
        pb = headB
        while pa != pb:
            pa = pa.next if pa else headB
            pb = pb.next if pb else headA
    
        return pa

# %%
#237. Delete Node in a Linked List
class Solution(object):
    def deleteNode(self, node):
        curr = node

        curr.val = curr.next.val
        curr.next  = curr.next.next
